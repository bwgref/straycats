# %%
from astropy.table import Table
import glob
import os

# %%
sf = '../straycats.fits'
straycat = Table.read(sf)

for key in straycat.columns:
    if straycat[key].dtype.str.startswith('|S'):
        straycat[key] = straycat[key].astype('str') 
df = straycat.to_pandas()

# %%
seqids = df['SEQID'].unique()

fig_dir = '/Users/bwgref/darkstar/Science/StrayCats/all_figs'

# %%
with open('missing_sl.txt', 'w') as f:
    for seqid in seqids:
        try:
            os.mkdir(f'seqid/{seqid}')
        except:
            pass
        
        sl_image = f'{fig_dir}/sl_images/{seqid}.pdf'
        if not os.path.isfile(sl_image):
            f.write(f'{seqid}\n')
            continue
        os.system(f'cp {fig_dir}/sl_images/{seqid}.pdf seqid/{seqid}/{seqid}_straylight.pdf')

# %%
with open('missing_map.txt', 'w') as f:
    for seqid in seqids:
        try:
            os.mkdir(f'seqid/{seqid}')
        except:
            pass
        
        sl_image = f'{fig_dir}/sl_estimates/{seqid}.pdf'
        if not os.path.isfile(sl_image):
            f.write(f'{seqid}\n')
        else:
            os.system(f'cp {fig_dir}/sl_estimates/{seqid}.pdf seqid/{seqid}/{seqid}_estimate.pdf')
        
        sl2_image = f'{fig_dir}/sl_estimates/{seqid}_v2.pdf'
        if not os.path.isfile(sl2_image):
            continue
        else:
            os.system(f'cp {fig_dir}/sl_estimates/{seqid}_v2.pdf seqid/{seqid}/{seqid}_transients.pdf')

# %%
sources = df['SL Source'].unique()
for source in sources:
    if source == '??':
        continue
    try:
        os.mkdir(f'sources/{source}')
    except:
        pass

    print(source)
    for seqid in df[df['SL Source']==source]['SEQID']:
        ss = f'seqid/{seqid}'
        if not os.path.isdir(ss):
            continue
        
        try:
            os.symlink( f'../../seqid/{seqid}',f'sources/{source}/{seqid}')
        except:
            pass
# Out:
# SMC X-1
# SMC X-3
# RX J0053.8-7226
# NGC 1275
# LMC X-2
# LMC X-4
# Crab
# LMC X-3
# LMC X-1
# Crab GR
# 4U 0614+091
# 2MASX J09172716-6456271
# Cen X-3
# A 1145.1-6141
# NGC 4151
# NGC 4388
# 3C 273
# GX 301-2
# Coma
# 4U 1323-619
# IC 4329A
# H1417-624
# MAXI J1348
# PSR 1509-58
# MAXI J1535
# Cir X-1
# 4U 1538-522
# MAXI J1621
# 4U 1624-490
# 4U 1636-536
# 4U 1702-429
# 4U 1705-44
# 4U 1608-522
# IGR 16320-4751
# GX 340+0
# MAXI J1631-479
# 4U 1630-47
# OAO 1657-415
# 4U 1708-40
# GX 349+2
# 4U 1700-377
# XTE J1701-407
# GS 1716-249
# 4U 1724-30
# GX 9+9
# GX 1+4
# GX 3+1
# 4U 1746-370
# IGRJ17498-2921
# SLX 1735-269
# IGR J17464-3213
# IGRJ17511-3057
# Rapid Burster
# GX 354+0
# GRS 1758-258
# GX 9+1
# SLX 1744-299
# GX 5-1
# GX 17+2
# SAX J1808.4-3658
# 4U 1822-371
# GX 13+1
# 1RXSJ180408.9-342058
# SAXJ1806.5-2215
# MAXI J1820
# GS 1826-24
# M1812-12
# 4U 1820-303
# XTE J1855-026
# EXO 1846-031
# X1908+075
# GRS 1915+105
# SS 433
# 4U 1909+07
# 4U 1907+097
# Cyg X-1
# EXO 2030+375
# Cyg X-3
# Cep X-4
# IGR J21247+5058
# Cas A
# 1A 0535+262
# 2S 0918-549
# GX 339-4

# %%
df
# Out:
#              STRAYID Classification        SEQID Module    Exposure Multi  \
# 0       StrayCatsI_0          Faint  30001014002      B  88472.3252     N
# 1       StrayCatsI_1           Unkn  90101010002      A  38102.7867     N
# 2       StrayCatsI_2             SL  90201030002      A  54920.5708     N
# 3       StrayCatsI_3             SL  90201041002      A  38601.5531     N
# 4       StrayCatsI_4             SL  30361002002      A  70650.3252     N
# ..               ...            ...          ...    ...         ...   ...
# 857  StrayCatsII_101             SL  90701306002      B  44607.4871     N
# 858  StrayCatsII_102             GR  40701002002      A  97596.2824     N
# 859  StrayCatsII_103             GR  40701002002      B  96644.4133     N
# 860  StrayCatsII_104             SL  90701336002      B  23583.9090     N
# 861  StrayCatsII_105             SL  90701312002      B  40852.2448     N
#
#                     Primary          TIME      END_TIME  RA_PRIMARY  \
# 0                   IC10_X1  56967.768139  56969.709111      5.0742
# 1           IGR_J00291p5934  57231.532039  57232.323706      7.2752
# 2      SWIFT_J003233d6m7306  57586.716067  57587.608428      8.1969
# 3                    SMC_X3  57704.740373  57705.608428     13.0299
# 4                  SXP_15d3  58087.025106  58088.636217     13.1118
# ..                      ...           ...           ...         ...
# 857     Swift_182251m135218  59265.966079  59267.011217    275.7079
# 858        W50_WESTERN_LOBE  59409.806356  59412.212606    287.6642
# 859        W50_WESTERN_LOBE  59409.806356  59412.212606    287.6642
# 860            EXO_2030p375  59526.146634  59526.747329    308.0343
# 861   PNV_J23244760p6111140  59293.955662  59294.611912    351.2713
#
#      DEC_PRIMARY SL Source  SL Type SIMBAD_ID       RA_SL      DEC_SL
# 0        59.2736        ??       ??        NA -999.000000 -999.000000
# 1        59.5982        ??       ??        NA -999.000000 -999.000000
# 2       -73.0956   SMC X-1  HMXB-NS   SMC X-1   19.271436  -73.443337
# 3       -72.4574   SMC X-1  HMXB-NS   SMC X-1   19.271436  -73.443337
# 4       -73.3731   SMC X-1  HMXB-NS   SMC X-1   19.271436  -73.443337
# ..           ...       ...      ...       ...         ...         ...
# 857     -13.8830   GX 17+2  LMXB-NS   GX 17+2  274.005787  -14.036283
# 858       5.0250        ??       ??        NA -999.000000 -999.000000
# 859       5.0250        ??       ??        NA -999.000000 -999.000000
# 860      37.5922   Cyg X-3  HMXB-BH   Cyg X-3  308.107417   40.957750
# 861      61.1574     Cas A      SNR     Cas A  350.850000   58.815000
#
# [862 rows x 16 columns]
