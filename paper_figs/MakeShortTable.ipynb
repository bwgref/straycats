# %%
from astropy.io.fits import getdata
straycats = getdata('../straycats.fits')

# %%
straycats
# Out:
# FITS_rec([('SL', '1RXSJ180408.9-342058', '??', 90102003002, 'A', 'N', 'SAX_J1808d4m3658', 57127.04244426, 57128.30980537, 4.92678000e+04, 272.1324, '-36.9541', 'Strong SL, unknown?'),
#           ('SL', '1RXSJ180408.9-342058', '??', 90102003004, 'A', 'N', 'SAX_J1808d4m3658', 57151.96952759, 57152.42786093, 2.15088000e+04, 272.1424, '-36.951', 'Strong, unident SL'),
#           ('SL', '1RXSJ180408.9-342058', '??', 90102003004, 'B', 'N', 'SAX_J1808d4m3658', 57151.96952759, 57152.42786093, 2.15088000e+04, 272.1424, '-36.951', 'Strong, unident SL'),
#           ('SL', '2MASX J09172716-6456271', 'AGN', 60401020002, 'A', 'N', 'IRAS_09149m6206', 58323.3063563 , 58325.78899519, 1.10899000e+05, 138.9791, '-62.3074', 'SL on both'),
#           ('SL', '2MASX J09172716-6456271', 'AGN', 60401020002, 'B', 'N', 'IRAS_09149m6206', 58323.3063563 , 58325.78899519, 1.10899000e+05, 138.9791, '-62.3074', 'SL in both'),
# ...
